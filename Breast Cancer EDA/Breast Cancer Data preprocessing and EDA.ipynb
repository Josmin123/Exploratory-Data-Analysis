# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
data=pd.read_csv('D:\Downloads\data.csv')
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
#finding missing values
data.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
#droping unwanted columns
data.drop(['Unnamed: 32','id'],axis=1,inplace=True)

# %%
data.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
data['radius_mean'].skew()
# Out:
# 0.9423795716730992

# %%
#outlier detections
sns.boxplot(x='radius_mean',data=data)
# Out:
# <Axes: xlabel='radius_mean'>

# %%
#finding the IQR
q1=data['radius_mean'].quantile(0.25)
q3=data['radius_mean'].quantile(0.75)

# %%
iqr=q3-q1
iqr
# Out:
# 4.08

# %%
upper_limit=q3+1.5*iqr
lower_limit=q1-1.5*iqr

# %%
#finding outliers
data[data['radius_mean']>upper_limit]
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 82          M        25.22         24.91           171.5     1878.0
# 108         M        22.27         19.67           152.8     1509.0
# 122         M        24.25         20.20           166.2     1761.0
# 164         M        23.27         22.04           152.1     1686.0
# 180         M        27.22         21.87           182.1     2250.0
# 202         M        23.29         26.67           158.9     1685.0
# 212         M        28.11         18.47           188.5     2499.0
# 236         M        23.21         26.97           153.5     1670.0
# 339         M        23.51         24.27           155.1     1747.0
# 352         M        25.73         17.46           174.2     2010.0
# 369         M        22.01         21.90           147.2     1482.0
# 461         M        27.42         26.27           186.9     2501.0
# 503         M        23.09         19.83           152.1     1682.0
# ...

# %%
data[data['radius_mean']<lower_limit]
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 3           M        11.42         20.38           77.58      386.1
# 5           M        12.45         15.70           82.57      477.1
# 7           M        13.71         20.83           90.20      577.9
# 8           M        13.00         21.82           87.50      519.8
# 9           M        12.46         24.04           83.97      475.9
# ..        ...          ...           ...             ...        ...
# 560         B        14.05         27.15           91.38      600.4
# 561         B        11.20         29.37           70.67      386.0
# 562         M        15.22         30.62          103.40      716.9
# 566         M        16.60         28.08          108.30      858.1
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
#TRIMMIMG
new_data=data[(data['radius_mean']<=upper_limit) & (data['radius_mean']>=lower_limit)]
new_data
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38           122.8     1001.0
# 1           M        20.57         17.77           132.9     1326.0
# 2           M        19.69         21.25           130.0     1203.0
# 4           M        20.29         14.34           135.1     1297.0
# 6           M        18.25         19.98           119.6     1040.0
# ..        ...          ...           ...             ...        ...
# 535         M        20.55         20.86           137.8     1308.0
# 563         M        20.92         25.09           143.0     1347.0
# 564         M        21.56         22.39           142.0     1479.0
# 565         M        20.13         28.25           131.2     1261.0
# 567         M        20.60         29.33           140.1     1265.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
new_data.shape
# Out:
# (84, 31)

# %%
sns.boxplot(x='radius_mean',data=new_data)
# Out:
# <Axes: xlabel='radius_mean'>

# %%
#capping
# new_df_cap=data.copy()
# new_df_cap['radius_mean']=np.where(new_df_cap['radius_mean']>upper_limit,upper_limit,np.where(new_df_cap['radius_mean']<lower_limit,lower_limit,new_df_cap['radius_mean']))

# %%
#Encode the diagnosis column
le=LabelEncoder()
data['diagnosis']=le.fit_transform(data['diagnosis'])

# %%
data.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
#1-->malignant
#0-->Begnin

# %%
#number of rows,columns
data.shape
# Out:
# (569, 31)

# %%
data.describe()
# Out:
#         diagnosis  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  569.000000   569.000000    569.000000      569.000000   569.000000
# mean     0.372583    14.127292     19.289649       91.969033   654.889104
# std      0.483918     3.524049      4.301036       24.298981   351.914129
# min      0.000000     6.981000      9.710000       43.790000   143.500000
# 25%      0.000000    11.700000     16.170000       75.170000   420.300000
# 50%      0.000000    13.370000     18.840000       86.240000   551.100000
# 75%      1.000000    15.780000     21.800000      104.100000   782.700000
# max      1.000000    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    int32
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
#checking the distribution of target variable
data['diagnosis'].value_counts()
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %%
data.groupby('diagnosis').mean()
# Out:
#            radius_mean  texture_mean  perimeter_mean   area_mean  \
# diagnosis
# 0            12.146524     17.914762       78.075406  462.790196
# 1            17.462830     21.604906      115.365377  978.376415
#
#            smoothness_mean  compactness_mean  concavity_mean  \
# diagnosis
# 0                 0.092478          0.080085        0.046058
# 1                 0.102898          0.145188        0.160775
#
#            concave points_mean  symmetry_mean  fractal_dimension_mean  ...  \
# diagnosis                                                              ...
# 0                     0.025717       0.174186                0.062867  ...
# 1                     0.087990       0.192909                0.062680  ...
#
#            radius_worst  texture_worst  perimeter_worst   area_worst  \
# diagnosis
# 0             13.379801      23.515070        87.005938   558.899440
# 1             21.134811      29.318208       141.370330  1422.286321
#
# ...

# %%
sns.countplot(x='diagnosis', hue='diagnosis', data=data)
# Out:
# <Axes: xlabel='diagnosis', ylabel='count'>

# %%
#splitting the data
x=data.drop('diagnosis',axis=1)
y=data['diagnosis']

# %%
x
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int32

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x.shape
# Out:
# (569, 30)

# %%
x_train.shape
# Out:
# (455, 30)

# %%
x_test.shape
# Out:
# (114, 30)

# %%
y_train.shape
# Out:
# (455,)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)
x_train_scaled
# Out:
# array([[-0.01330339,  1.7757658 , -0.01491962, ..., -0.13236958,
#         -1.08014517, -0.03527943],
#        [-0.8448276 , -0.6284278 , -0.87702746, ..., -1.11552632,
#         -0.85773964, -0.72098905],
#        [ 1.44755936,  0.71180168,  1.47428816, ...,  0.87583964,
#          0.4967602 ,  0.46321706],
#        ...,
#        [-0.46608541, -1.49375484, -0.53234924, ..., -1.32388956,
#         -1.02997851, -0.75145272],
#        [-0.50025764, -1.62161319, -0.527814  , ..., -0.0987626 ,
#          0.35796577, -0.43906159],
#        [ 0.96060511,  1.21181916,  1.00427242, ...,  0.8956983 ,
#         -1.23064515,  0.50697397]])

# %%
x_test_scaled
# Out:
# array([[-0.04462793, -1.41612656, -0.05903514, ..., -0.18278004,
#         -1.23064515, -0.6268286 ],
#        [ 0.24583601, -0.06219797,  0.21802678, ...,  0.54129749,
#          0.11047691,  0.0483572 ],
#        [-1.26115925, -0.29051645, -1.26499659, ..., -1.35138617,
#          0.269338  , -0.28231213],
#        ...,
#        [ 0.72709489,  0.45836817,  0.75277276, ...,  1.46701686,
#          1.19909344,  0.65319961],
#        [ 0.25437907,  1.33054477,  0.15659489, ..., -1.29043534,
#         -2.22561725, -1.59557344],
#        [ 0.84100232, -0.06676434,  0.8929529 , ...,  2.15137705,
#          0.35629355,  0.37459546]])

# %%
#handle imbalnce dataset
# Before oversampling
print(pd.Series(y_train).value_counts())
# Out:
# 0    288
# 1    167
# Name: diagnosis, dtype: int64

# %%
# Apply SMOTE
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=0)
x_train, y_train = sm.fit_resample(x_train, y_train)

# %%
# After oversampling
print(pd.Series(y_train).value_counts())

# %%
print("Shape of X_train after SMOTE:", x_train.shape)

# %%
# Visualize the distribution of the target variable
sns.countplot(x='diagnosis', data=data)

# %%
# Visualize the distribution of each feature with a histogram
data.hist(figsize=(20,20))
plt.show()

# %%
# Visualize the relationship between features for both classes of the target variable with a pairplot
sns.pairplot(data, hue='diagnosis', vars=['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean'])

# %%
# Visualize the correlation matrix between features
#Using Pearson Correlation
plt.figure(figsize=(20,20))
cor = x_train.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
# with the following function we can select highly correlated features
# it will remove the first feature that is correlated with anything other feature

def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(x_train, 0.9)
len(set(corr_features))
# Out:
# 10

# %%
corr_features
# Out:
# {'area_mean',
#  'area_se',
#  'area_worst',
#  'concave points_mean',
#  'concave points_worst',
#  'perimeter_mean',
#  'perimeter_se',
#  'perimeter_worst',
#  'radius_worst',
#  'texture_worst'}

# %%
x_train.drop(corr_features,axis=1)
x_test.drop(corr_features,axis=1)
# Out:
#      radius_mean  texture_mean  smoothness_mean  compactness_mean  \
# 528       13.940         13.17          0.12480           0.09755
# 291       14.960         19.10          0.08992           0.09823
# 467        9.668         18.10          0.08311           0.05428
# 108       22.270         19.67          0.13260           0.27680
# 340       14.420         16.54          0.09751           0.11390
# ..           ...           ...              ...               ...
# 471       12.040         28.14          0.08752           0.06000
# 449       21.100         20.52          0.09684           0.11750
# 24        16.650         21.38          0.11210           0.14570
# 38        14.990         25.20          0.09387           0.05131
# 230       17.050         19.08          0.11410           0.15720
#
#      concavity_mean  symmetry_mean  fractal_dimension_mean  radius_se  \
# 528         0.10100         0.1976                 0.06457     0.5461
# ...
